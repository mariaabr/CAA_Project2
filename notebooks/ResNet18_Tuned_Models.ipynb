# %% [markdown]
# # Deep Learning Architectures for Pneumonia Detection: Multi-Scale Analysis with Explainable AI
#
# **ResNet18 Fine-Tuned Models Notebook**
#
# **Description:** This notebook fine-tunes the best performing ResNet18 model on higher resolution images (64x64) to improve performance for subsequent XAI analysis.
#
# Authors:
# - Rafaela Abrunhosa, 107658
# - Miguel Pinto, 107449

# %%
# Clona apenas a branch fine_tuning
# !git clone --branch fine_tuning --single-branch https://github.com/mariaabr/CAA_Project2.git

# Monta o Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Copia a pasta 'data' do Drive para o repositório
# !cp -r /content/drive/MyDrive/data /content/CAA_Project2/

# Copia os modelos para o repositório
# !cp -r /content/drive/MyDrive/models /content/CAA_Project2/output/
# Out:
# Cloning into 'CAA_Project2'...
# remote: Enumerating objects: 428, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 428 (delta 50), reused 78 (delta 36), pack-reused 327 (from 1)
# Receiving objects: 100% (428/428), 18.91 MiB | 16.72 MiB/s, done.
# Resolving deltas: 100% (247/247), done.
# Mounted at /content/drive

# %%
# Entra na pasta dos notebooks
# %cd CAA_Project2/notebooks
# Out:
# /content/CAA_Project2/notebooks

# %% [markdown]
# # External Libraries

# %%
# Import utility libraries
import os
import sys
import time
from datetime import datetime
sys.path.append('..')  # Add parent directory to path to allow import of custom modules

# Import deep learning libraries
import tensorflow as tf

# Suppress TensorFlow warnings
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # 0=all, 1=info, 2=warning, 3=error
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'   # Disable oneDNN optimizations for reproducibility

# Disable verbose output from TensorFlow during training
tf_verbosity = 1  # 0 = silent, 1 = progress bar, 2 = one line per epoch

# Import custom utilities
from utils.data_utils import load_and_preprocess_multiscale_data
from utils.finetune_utils import (
    load_pretrained_model, extract_model_params,
    freeze_layers, generate_tuned_model_path
)
from utils.model.resnet_utils import adapt_resnet18_for_resolution, transfer_resnet18_weights
from utils.train_utils import get_callbacks
from utils.eval_utils import evaluate_model
from utils.plot_utils import plot_training_history, plot_roc_curve, plot_confusion_matrix
from utils.logger_utils import ModelLogger

# %% [markdown]
# # Core Variables

# %%
# Global seed for reproducibility
RANDOM_SEED = 42

# Architecture and paths
ARCHITECTURE = 'resnet_18'                # Architecture name
DATA_PATH = '../data/'                    # Path to the dataset
OUTPUT_PATH = '../output/'                # Path to save output files
MODEL_PATH = OUTPUT_PATH + 'models/'      # Path to save models
LOG_PATH = OUTPUT_PATH + 'logs/'          # Path to save logs

# Fine-tuning parameters
ORIGINAL_SIZE = 28                        # Original training image size
TARGET_SIZE = 128                         # Target fine-tuning image size
FINE_TUNE_LR = 0.0001                     # Lower learning rate for fine-tuning (10x reduction)
FINE_TUNE_EPOCHS = 30                     # Number of fine-tuning epochs

# ResNet18-specific freeze ratio
# Higher ratio = more frozen layers = preserves more pre-trained features
# Lower ratio = fewer frozen layers = allows more adaptation to new resolution
FREEZE_RATIO = 0.60    # ResNet18: 60% - lower due to residual connections

print(f"Using freeze ratio for {ARCHITECTURE}: {FREEZE_RATIO*100:.0f}%")

# Ensure directories exist
os.makedirs(MODEL_PATH, exist_ok=True)
os.makedirs(LOG_PATH, exist_ok=True)
# Out:
# Using freeze ratio for resnet_18: 60%

# %% [markdown]
# # Best Pre-trained Model Loading

# %%
# Load the specified pre-trained model
MODEL_FILENAME = 'resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras'
best_model_path = os.path.join(MODEL_PATH, MODEL_FILENAME)

print(f"Loading pre-trained model: {best_model_path}")
pretrained_model = load_pretrained_model(best_model_path)
print(f"✓ Loaded model with {pretrained_model.count_params():,} parameters")

# Extract parameters from the model filename
original_params = extract_model_params(MODEL_FILENAME)
print("Parameters extracted from model filename:")
for key, value in original_params.items():
    print(f"  {key}: {value}")
# Out:
# Loading pre-trained model: ../output/models/resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras
# Loading model from: ../output/models/resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras
# Model loaded successfully: functional_3
# ✓ Loaded model with 11,183,106 parameters
# Parameters extracted from model filename:
#   batch_size: 64
#   learning_rate: 0.001
#   dropout_rate: 0.5
#   augmented: True
#   dropout_mode: fixed

# %% [markdown]
# # Data Loading & Preprocessing

# %%
# Load data with target resolution
print(f"Loading data with {TARGET_SIZE}x{TARGET_SIZE} resolution...")
train_dataset, (test_images, test_labels), (val_images, val_labels) = load_and_preprocess_multiscale_data(
    DATA_PATH,
    image_size=TARGET_SIZE,
    augment=original_params['augmented'],  # Use same augmentation as original model
    batch_size=original_params['batch_size'],
    seed=RANDOM_SEED
)
print(f"✓ Data loaded successfully")
# Out:
# Loading data with 128x128 resolution...
#
# Dataset shapes - 128x128 resolution:
# Train - images: (4708, 128, 128)  labels: (4708, 1)
# Val   - images: (524, 128, 128)  labels: (524, 1)
# Test  - images: (624, 128, 128)  labels: (624, 1)
# ✓ Data loaded successfully

# %% [markdown]
# # Model Adaptation

# %%
# Adapt the ResNet18 model for the new resolution
print(f"\nAdapting ResNet18 from {ORIGINAL_SIZE}x{ORIGINAL_SIZE} to {TARGET_SIZE}x{TARGET_SIZE}...")

adapted_model = adapt_resnet18_for_resolution(
    pretrained_model,
    TARGET_SIZE,
    dropout_rate=original_params['dropout_rate']
)

print(f"✓ ResNet18 successfully adapted from {ORIGINAL_SIZE}x{ORIGINAL_SIZE} to {TARGET_SIZE}x{TARGET_SIZE}")

# Transfer weights from the original model to the adapted model
print("Transferring compatible weights...")
adapted_model = transfer_resnet18_weights(pretrained_model, adapted_model)

# Freeze layers for fine-tuning
print(f"\nApplying freeze ratio of {FREEZE_RATIO*100:.0f}%...")
adapted_model = freeze_layers(adapted_model, freeze_ratio=FREEZE_RATIO)

print(f"\nModel adaptation complete for fine-tuning:")
print(f"  Architecture: ResNet18")
print(f"  Original resolution: {ORIGINAL_SIZE}x{ORIGINAL_SIZE}")
print(f"  Target resolution: {TARGET_SIZE}x{TARGET_SIZE}")
print(f"  Freeze ratio: {FREEZE_RATIO*100:.0f}%")
# Out:
# Adapting ResNet18 from 28x28 to 128x128...
# Building new ResNet18 for 128x128 resolution...
# Using dropout rate: 0.5
# ✓ ResNet18 successfully adapted from (None, 28, 28, 1) to (128, 128, 1)
# Original parameters: 11,183,106
# Adapted parameters: 11,183,106
# ✓ ResNet18 successfully adapted from 28x28 to 128x128
# Transferring compatible weights...
#
# Transferring ResNet18 weights...
# ✓ Conv2D layer conv1: 64 filters
# ✓ BatchNorm layer bn1
# ✓ Conv2D layer stage1_block1_conv1: 64 filters
# ✓ BatchNorm layer stage1_block1_bn1
# ✓ Conv2D layer stage1_block1_conv2: 64 filters
# ✓ BatchNorm layer stage1_block1_bn2
# ✓ Conv2D layer stage1_block2_conv1: 64 filters
# ✓ BatchNorm layer stage1_block2_bn1
# ✓ Conv2D layer stage1_block2_conv2: 64 filters
# ✓ BatchNorm layer stage1_block2_bn2
# ✓ Conv2D layer stage2_block1_conv1: 128 filters
# ✓ BatchNorm layer stage2_block1_bn1
# ✓ Conv2D layer stage2_block1_conv2: 128 filters
# ✓ Conv2D layer stage2_block1_shortcut_conv: 128 filters
# ✓ BatchNorm layer stage2_block1_bn2
# ✓ BatchNorm layer stage2_block1_shortcut_bn
# ✓ Conv2D layer stage2_block2_conv1: 128 filters
# ✓ BatchNorm layer stage2_block2_bn1
# ✓ Conv2D layer stage2_block2_conv2: 128 filters
# ✓ BatchNorm layer stage2_block2_bn2
# ✓ Conv2D layer stage3_block1_conv1: 256 filters
# ✓ BatchNorm layer stage3_block1_bn1
# ✓ Conv2D layer stage3_block1_conv2: 256 filters
# ✓ Conv2D layer stage3_block1_shortcut_conv: 256 filters
# ✓ BatchNorm layer stage3_block1_bn2
# ✓ BatchNorm layer stage3_block1_shortcut_bn
# ✓ Conv2D layer stage3_block2_conv1: 256 filters
# ✓ BatchNorm layer stage3_block2_bn1
# ✓ Conv2D layer stage3_block2_conv2: 256 filters
# ✓ BatchNorm layer stage3_block2_bn2
# ✓ Conv2D layer stage4_block1_conv1: 512 filters
# ✓ BatchNorm layer stage4_block1_bn1
# ✓ Conv2D layer stage4_block1_conv2: 512 filters
# ✓ Conv2D layer stage4_block1_shortcut_conv: 512 filters
# ✓ BatchNorm layer stage4_block1_bn2
# ✓ BatchNorm layer stage4_block1_shortcut_bn
# ✓ Conv2D layer stage4_block2_conv1: 512 filters
# ✓ BatchNorm layer stage4_block2_bn1
# ✓ Conv2D layer stage4_block2_conv2: 512 filters
# ✓ BatchNorm layer stage4_block2_bn2
# ✓ Dense layer fc: 2 units
#
# ResNet18 weight transfer complete: 41 layers transferred
#
# Applying freeze ratio of 60%...
# Frozen layers: 42
# Trainable layers: 28
#
# Model adaptation complete for fine-tuning:
#   Architecture: ResNet18
#   Original resolution: 28x28
#   Target resolution: 128x128
#   Freeze ratio: 60%

# %% [markdown]
# # Model Compilation

# %%
# Compile for fine-tuning with lower learning rate
adapted_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',  # Updated to match one-hot encoded labels
    metrics=['accuracy', 'AUC']
)

print(f"\nModel compiled for fine-tuning:")
print(f"  Optimizer: Adam (lr={FINE_TUNE_LR})")
print(f"  Loss: Categorical crossentropy")
print(f"  Metrics: Accuracy, AUC")

adapted_model.summary()
# Out:
# Model compiled for fine-tuning:
#   Optimizer: Adam (lr=0.0001)
#   Loss: Categorical crossentropy
#   Metrics: Accuracy, AUC
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 128, 128,  │        640 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 128, 128,  │        256 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, 128, 128,  │          0 │ bn1[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 64, 64,    │          0 │ relu1[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv1 │ (None, 64, 64,    │     36,928 │ maxpool1[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn1   │ (None, 64, 64,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu1 │ (None, 64, 64,    │          0 │ stage1_block1_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv2 │ (None, 64, 64,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn2   │ (None, 64, 64,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_add   │ (None, 64, 64,    │          0 │ stage1_block1_bn… │
# │ (Add)               │ 64)               │            │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu2 │ (None, 64, 64,    │          0 │ stage1_block1_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv1 │ (None, 64, 64,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn1   │ (None, 64, 64,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu1 │ (None, 64, 64,    │          0 │ stage1_block2_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv2 │ (None, 64, 64,    │     36,928 │ stage1_block2_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn2   │ (None, 64, 64,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_add   │ (None, 64, 64,    │          0 │ stage1_block2_bn… │
# │ (Add)               │ 64)               │            │ stage1_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu2 │ (None, 64, 64,    │          0 │ stage1_block2_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv1 │ (None, 32, 32,    │     73,856 │ stage1_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn1   │ (None, 32, 32,    │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu1 │ (None, 32, 32,    │          0 │ stage2_block1_bn… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv2 │ (None, 32, 32,    │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 32, 32,    │      8,320 │ stage1_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn2   │ (None, 32, 32,    │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 32, 32,    │        512 │ stage2_block1_sh… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 32, 32,    │          0 │ stage2_block1_bn… │
# │ (Add)               │ 128)              │            │ stage2_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu2 │ (None, 32, 32,    │          0 │ stage2_block1_ad… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv1 │ (None, 32, 32,    │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn1   │ (None, 32, 32,    │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu1 │ (None, 32, 32,    │          0 │ stage2_block2_bn… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv2 │ (None, 32, 32,    │    147,584 │ stage2_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn2   │ (None, 32, 32,    │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 32, 32,    │          0 │ stage2_block2_bn… │
# │ (Add)               │ 128)              │            │ stage2_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu2 │ (None, 32, 32,    │          0 │ stage2_block2_ad… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv1 │ (None, 16, 16,    │    295,168 │ stage2_block2_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn1   │ (None, 16, 16,    │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu1 │ (None, 16, 16,    │          0 │ stage3_block1_bn… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv2 │ (None, 16, 16,    │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 16, 16,    │     33,024 │ stage2_block2_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn2   │ (None, 16, 16,    │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 16, 16,    │      1,024 │ stage3_block1_sh… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 16, 16,    │          0 │ stage3_block1_bn… │
# │ (Add)               │ 256)              │            │ stage3_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu2 │ (None, 16, 16,    │          0 │ stage3_block1_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv1 │ (None, 16, 16,    │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn1   │ (None, 16, 16,    │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu1 │ (None, 16, 16,    │          0 │ stage3_block2_bn… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv2 │ (None, 16, 16,    │    590,080 │ stage3_block2_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn2   │ (None, 16, 16,    │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 16, 16,    │          0 │ stage3_block2_bn… │
# │ (Add)               │ 256)              │            │ stage3_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu2 │ (None, 16, 16,    │          0 │ stage3_block2_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv1 │ (None, 8, 8, 512) │  1,180,160 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn1   │ (None, 8, 8, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu1 │ (None, 8, 8, 512) │          0 │ stage4_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv2 │ (None, 8, 8, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 8, 8, 512) │    131,584 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn2   │ (None, 8, 8, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 8, 8, 512) │      2,048 │ stage4_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 8, 8, 512) │          0 │ stage4_block1_bn… │
# │ (Add)               │                   │            │ stage4_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu2 │ (None, 8, 8, 512) │          0 │ stage4_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv1 │ (None, 8, 8, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn1   │ (None, 8, 8, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu1 │ (None, 8, 8, 512) │          0 │ stage4_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv2 │ (None, 8, 8, 512) │  2,359,808 │ stage4_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn2   │ (None, 8, 8, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 8, 8, 512) │          0 │ stage4_block2_bn… │
# │ (Add)               │                   │            │ stage4_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu2 │ (None, 8, 8, 512) │          0 │ stage4_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ stage4_block2_re… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc (Dense)          │ (None, 2)         │      1,026 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,183,106 (42.66 MB)
#  Trainable params: 9,578,498 (36.54 MB)
#  Non-trainable params: 1,604,608 (6.12 MB)

# %% [markdown]
# # Fine-tuning Setup

# %%
# Generate path for fine-tuned model
tuned_model_path = generate_tuned_model_path(
    original_params,
    TARGET_SIZE,
    MODEL_PATH,
    ARCHITECTURE
)
print(f"Fine-tuned model will be saved to: {tuned_model_path}")

# Setup logger for fine-tuning
logger = ModelLogger()
tuned_model_info = {
    "model_name": f"{ARCHITECTURE}_tuned",
    "original_model": best_model_path,
    "original_size": ORIGINAL_SIZE,
    "target_size": TARGET_SIZE,
    "fine_tune_lr": FINE_TUNE_LR,
    "freeze_ratio": FREEZE_RATIO,
    "epochs": FINE_TUNE_EPOCHS,
    "batch_size": original_params['batch_size'],
    "augmented": original_params['augmented'],
    "dropout_rate": original_params['dropout_rate'],
    "random_seed": RANDOM_SEED
}
logger.initialize_run(tuned_model_info)
# Out:
# Fine-tuned model will be saved to: ../output/models/resnet_18_tuned_augmented_b64_lr0.001_dr0.5_128px_pneumonia_model.keras

# %% [markdown]
# # Fine-tuning Process

# %%
# Get callbacks for fine-tuning
callbacks = get_callbacks(
    tuned_model_path,
    monitor='val_AUC',
    mode='max',
    patience=10,
    factor=0.5  # Use lower factor for fine-tuning (more aggressive LR reduction)
)

# Start fine-tuning
print(f"\nStarting fine-tuning for {FINE_TUNE_EPOCHS} epochs...")
start_time = time.time()

history = adapted_model.fit(
    train_dataset,
    validation_data=(val_images, val_labels),
    epochs=FINE_TUNE_EPOCHS,
    callbacks=callbacks,
    verbose=tf_verbosity
)

exec_time = round(time.time() - start_time, 2)
print(f"\nFine-tuning completed in {exec_time} seconds")

# Save training info to logger
logger.add_training_info(history, exec_time)

# Set final model for evaluation
final_model = adapted_model

print("✓ Fine-tuning completed successfully!")

# Plot training history
plot_training_history(history)
# Out:
# Starting fine-tuning for 30 epochs...
# Epoch 1/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 58s 536ms/step - AUC: 0.8848 - accuracy: 0.8212 - loss: 0.8785 - val_AUC: 0.9098 - val_accuracy: 0.7443 - val_loss: 0.7686 - learning_rate: 1.0000e-04
# Epoch 2/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 280ms/step - AUC: 0.9662 - accuracy: 0.9035 - loss: 0.2401 - val_AUC: 0.9787 - val_accuracy: 0.9256 - val_loss: 0.2025 - learning_rate: 1.0000e-04
# Epoch 3/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 263ms/step - AUC: 0.9788 - accuracy: 0.9208 - loss: 0.1878 - val_AUC: 0.9812 - val_accuracy: 0.9313 - val_loss: 0.1909 - learning_rate: 1.0000e-04
# Epoch 4/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 283ms/step - AUC: 0.9812 - accuracy: 0.9267 - loss: 0.1748 - val_AUC: 0.9822 - val_accuracy: 0.9237 - val_loss: 0.1895 - learning_rate: 1.0000e-04
# Epoch 5/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - AUC: 0.9842 - accuracy: 0.9387 - loss: 0.1603 - val_AUC: 0.9788 - val_accuracy: 0.9122 - val_loss: 0.1911 - learning_rate: 1.0000e-04
# Epoch 6/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 266ms/step - AUC: 0.9860 - accuracy: 0.9373 - loss: 0.1498 - val_AUC: 0.9536 - val_accuracy: 0.8702 - val_loss: 0.2719 - learning_rate: 1.0000e-04
# Epoch 7/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 280ms/step - AUC: 0.9842 - accuracy: 0.9340 - loss: 0.1611 - val_AUC: 0.9905 - val_accuracy: 0.9427 - val_loss: 0.1281 - learning_rate: 1.0000e-04
# Epoch 8/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - AUC: 0.9882 - accuracy: 0.9466 - loss: 0.1365 - val_AUC: 0.9923 - val_accuracy: 0.9504 - val_loss: 0.1158 - learning_rate: 1.0000e-04
# Epoch 9/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 274ms/step - AUC: 0.9853 - accuracy: 0.9421 - loss: 0.1529 - val_AUC: 0.9892 - val_accuracy: 0.9561 - val_loss: 0.1271 - learning_rate: 1.0000e-04
# Epoch 10/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 19s 256ms/step - AUC: 0.9891 - accuracy: 0.9505 - loss: 0.1301 - val_AUC: 0.9885 - val_accuracy: 0.9485 - val_loss: 0.1320 - learning_rate: 1.0000e-04
# Epoch 11/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - AUC: 0.9924 - accuracy: 0.9567 - loss: 0.1112 - val_AUC: 0.9942 - val_accuracy: 0.9676 - val_loss: 0.0982 - learning_rate: 1.0000e-04
# Epoch 12/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - AUC: 0.9920 - accuracy: 0.9560 - loss: 0.1109 - val_AUC: 0.9938 - val_accuracy: 0.9676 - val_loss: 0.0901 - learning_rate: 1.0000e-04
# Epoch 13/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 269ms/step - AUC: 0.9924 - accuracy: 0.9564 - loss: 0.1101 - val_AUC: 0.9949 - val_accuracy: 0.9656 - val_loss: 0.0927 - learning_rate: 1.0000e-04
# Epoch 14/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 280ms/step - AUC: 0.9929 - accuracy: 0.9613 - loss: 0.1041 - val_AUC: 0.9915 - val_accuracy: 0.9523 - val_loss: 0.1153 - learning_rate: 1.0000e-04
# Epoch 15/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - AUC: 0.9908 - accuracy: 0.9562 - loss: 0.1151 - val_AUC: 0.9937 - val_accuracy: 0.9618 - val_loss: 0.1032 - learning_rate: 1.0000e-04
# Epoch 16/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - AUC: 0.9935 - accuracy: 0.9617 - loss: 0.0996 - val_AUC: 0.9604 - val_accuracy: 0.8893 - val_loss: 0.2691 - learning_rate: 1.0000e-04
# Epoch 17/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 19s 256ms/step - AUC: 0.9938 - accuracy: 0.9625 - loss: 0.0965 - val_AUC: 0.9919 - val_accuracy: 0.9656 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 18/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - AUC: 0.9963 - accuracy: 0.9703 - loss: 0.0756 - val_AUC: 0.9938 - val_accuracy: 0.9733 - val_loss: 0.0858 - learning_rate: 5.0000e-05
# Epoch 19/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 19s 254ms/step - AUC: 0.9955 - accuracy: 0.9716 - loss: 0.0809 - val_AUC: 0.9936 - val_accuracy: 0.9733 - val_loss: 0.0935 - learning_rate: 5.0000e-05
# Epoch 20/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 22s 269ms/step - AUC: 0.9966 - accuracy: 0.9758 - loss: 0.0704 - val_AUC: 0.9922 - val_accuracy: 0.9599 - val_loss: 0.1163 - learning_rate: 5.0000e-05
# Epoch 21/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - AUC: 0.9959 - accuracy: 0.9694 - loss: 0.0801 - val_AUC: 0.9936 - val_accuracy: 0.9637 - val_loss: 0.0982 - learning_rate: 5.0000e-05
# Epoch 22/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 274ms/step - AUC: 0.9961 - accuracy: 0.9738 - loss: 0.0732 - val_AUC: 0.9941 - val_accuracy: 0.9618 - val_loss: 0.0946 - learning_rate: 5.0000e-05
# Epoch 23/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 19s 257ms/step - AUC: 0.9951 - accuracy: 0.9667 - loss: 0.0858 - val_AUC: 0.9885 - val_accuracy: 0.9599 - val_loss: 0.1123 - learning_rate: 5.0000e-05
#
# Fine-tuning completed in 606.79 seconds
# ✓ Fine-tuning completed successfully!

# %% [markdown]
# # Model Evaluation

# %%
# Evaluate the fine-tuned model (using model from memory)
print("\nEvaluating fine-tuned model on test set...")

# Evaluate using the final model
results = evaluate_model(final_model, test_images, test_labels, verbose=tf_verbosity)

# Add evaluation results to logger
logger.add_evaluation_results(results)

# Plot results
plot_roc_curve(results['roc']['fpr'], results['roc']['tpr'], results['roc']['auc'])
plot_confusion_matrix(results['confusion_matrix'])
print("\nClassification Report:")
print(results['classification_report'])
# Out:
# Evaluating fine-tuned model on test set...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - AUC: 0.9542 - accuracy: 0.9119 - loss: 0.3181
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step
# ROC AUC Score: 0.970042
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.78      0.86       234
#    Pneumonia       0.88      0.98      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.92      0.88      0.90       624
# weighted avg       0.91      0.91      0.90       624

# %% [markdown]
# # Results Saving

# %%
# Save fine-tuning log
tuned_log_path = os.path.join(LOG_PATH, f"{ARCHITECTURE}_tuned_{TARGET_SIZE}px_info.json")
logger.save(tuned_log_path)

print(f"\n✅ Fine-tuning completed successfully!")
print(f"📁 Model saved: {tuned_model_path}")
print(f"📊 Logs saved: {tuned_log_path}")
print(f"🎯 Final accuracy: {results['test_accuracy']:.4f}")
print(f"📈 Final AUC: {results['test_auc']:.4f}")
print(f"🔍 The ResNet18 model is now ready for XAI analysis at {TARGET_SIZE}x{TARGET_SIZE} resolution.")
# Out:
# Run information saved to ../output/logs/resnet_18_tuned_128px_info.json
#
# ✅ Fine-tuning completed successfully!
# 📁 Model saved: ../output/models/resnet_18_tuned_augmented_b64_lr0.001_dr0.5_128px_pneumonia_model.keras
# 📊 Logs saved: ../output/logs/resnet_18_tuned_128px_info.json
# 🎯 Final accuracy: 0.9071
# 📈 Final AUC: 0.9551
# 🔍 The ResNet18 model is now ready for XAI analysis at 128x128 resolution.
