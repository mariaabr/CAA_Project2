# %% [markdown]
# # CAA Project - Deep Learning Approaches for Pneumonia Detection: A Comparative Study on Chest X-Ray Images
#
# **ResNet-18 Augmented Models Notebook**
#
# **Description:** This is the Jupyter Notebook training and evaluating a ResNet-18 model on the Pneumonia dataset with data augmentation.
#
# Authors:
# - Rafaela Abrunhosa, 107658
# - Miguel Pinto, 107449

# %% [markdown]
# # External Libraries

# %%
# Import utility libraries
import os
import sys
import time
from datetime import datetime
sys.path.append('..')  # Add parent directory to path to allow import of custom modules

# Import deep learning libraries
import tensorflow as tf

# Suppress TensorFlow warnings
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # 0=all, 1=info, 2=warning, 3=error
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'   # Disable oneDNN optimizations for reproducibility

# Disable verbose output from TensorFlow during training
tf_verbosity = 1  # 0 = silent, 1 = progress bar, 2 = one line per epoch

# Import custom utilities
from utils.data_utils import load_and_preprocess_data
from utils.model.resnet_utils import build_resnet18, DropoutRateScheduler
from utils.train_utils import get_callbacks
from utils.eval_utils import evaluate_model
from utils.plot_utils import plot_training_history, plot_roc_curve, plot_confusion_matrix
from utils.logger_utils import ModelLogger

# %% [markdown]
# # Core Variables

# %%
# Global seed for reproducibility
RANDOM_SEED = 42

# Path variables
DATA_PATH = '../data/'                                          # Path to the dataset
OUTPUT_PATH = '../output/'                                      # Path to save output files
MODEL_PATH = OUTPUT_PATH + 'models/'                            # Path to save the model
MODEL_NAME = 'resnet_18_augmented'                              # Name of the model to be saved
LOG_PATH = OUTPUT_PATH + 'logs/'+ MODEL_NAME + '_info.json'     # Path to save model metrics

# Ensure directories exist
os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
os.makedirs(os.path.dirname(LOG_PATH), exist_ok=True)

# %%
# Training parameters
EPOCHS = 100                # Number of epochs to train
BATCH_SIZE = 96             # Batch size for training
LEARNING_RATE = 0.001       # Learning rate for the optimizer

# Dropout parameters
DROPOUT_MODE = "custom"     # Dropout mode: "fixed" or "custom"
DROPOUT_RATE = 0.3          # Fixed dropout rate
DROPOUT_RATE_START = 0.5    # Starting rate for scheduler
DROPOUT_RATE_END = 0.3      # Ending rate for scheduler

# Model selection parameters
CHOSEN_METRIC = 'val_AUC'   # Metric to be used for model selection
MODE = 'max'                # Whether to maximize or minimize the chosen metric

# Final model path
if DROPOUT_MODE == "fixed":
    FINAL_MODEL_PATH = f'{MODEL_PATH}{MODEL_NAME}_b{BATCH_SIZE}_lr{LEARNING_RATE}_dr{DROPOUT_RATE}_pneumonia_model.keras'
elif DROPOUT_MODE == "custom":
    FINAL_MODEL_PATH = f'{MODEL_PATH}{MODEL_NAME}_b{BATCH_SIZE}_lr{LEARNING_RATE}_dr{DROPOUT_RATE_START}_{DROPOUT_RATE_END}_pneumonia_model.keras'

# Create model logger
logger = ModelLogger()

# %% [markdown]
# # Data Loading & Preprocessing

# %%
train_dataset, (test_images, test_labels), (val_images, val_labels) = load_and_preprocess_data(
        DATA_PATH,
        augment=True,
        batch_size=BATCH_SIZE,
        seed=RANDOM_SEED
    )
# Out:
# Dataset shapes - Original:
# Train - images: (4708, 28, 28)  labels: (4708, 1)
# Val   - images: (524, 28, 28)  labels: (524, 1)
# Test  - images: (624, 28, 28)  labels: (624, 1)
#
# Dataset shapes - After preprocessing:
# Train images shape: (4708, 28, 28, 1)
# Train labels shape: (4708, 2)
# Val images shape: (524, 28, 28, 1)
# Val labels shape: (524, 2)
# Test images shape: (624, 28, 28, 1)
# Test labels shape: (624, 2)
#
# Applying data augmentation to training data...

# %% [markdown]
# # ResNet-18 Model

# %% [markdown]
# ## Creation & Compilation

# %%
# Initialize model info for logging
model_info = {
    "model_name": MODEL_NAME,
    "learning_rate": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "epochs": EPOCHS,
    "dropout_mode": DROPOUT_MODE,
    "dropout_rate": DROPOUT_RATE if DROPOUT_MODE == "fixed" else None,
    "dropout_start": DROPOUT_RATE_START if DROPOUT_MODE == "custom" else None,
    "dropout_end": DROPOUT_RATE_END if DROPOUT_MODE == "custom" else None,
    "random_seed": RANDOM_SEED
}

# Initialize logger with model info
logger.initialize_run(model_info)

# %%
# Create and compile model
if DROPOUT_MODE == "fixed":
    model = build_resnet18(dropout_rate=DROPOUT_RATE)
elif DROPOUT_MODE == "custom":
    model = build_resnet18(dropout_rate=DROPOUT_RATE_START)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='binary_crossentropy',
    metrics=['accuracy', 'AUC']
)
model.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 28, 28,    │        640 │ input_layer_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 28, 28,    │        256 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, 28, 28,    │          0 │ bn1[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 14, 14,    │          0 │ relu1[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv1 │ (None, 14, 14,    │     36,928 │ maxpool1[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn1   │ (None, 14, 14,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu1 │ (None, 14, 14,    │          0 │ stage1_block1_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv2 │ (None, 14, 14,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn2   │ (None, 14, 14,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_add   │ (None, 14, 14,    │          0 │ stage1_block1_bn… │
# │ (Add)               │ 64)               │            │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu2 │ (None, 14, 14,    │          0 │ stage1_block1_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv1 │ (None, 14, 14,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn1   │ (None, 14, 14,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu1 │ (None, 14, 14,    │          0 │ stage1_block2_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv2 │ (None, 14, 14,    │     36,928 │ stage1_block2_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn2   │ (None, 14, 14,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_add   │ (None, 14, 14,    │          0 │ stage1_block2_bn… │
# │ (Add)               │ 64)               │            │ stage1_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu2 │ (None, 14, 14,    │          0 │ stage1_block2_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv1 │ (None, 7, 7, 128) │     73,856 │ stage1_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn1   │ (None, 7, 7, 128) │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu1 │ (None, 7, 7, 128) │          0 │ stage2_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv2 │ (None, 7, 7, 128) │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 7, 7, 128) │      8,320 │ stage1_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn2   │ (None, 7, 7, 128) │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 7, 7, 128) │        512 │ stage2_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 7, 7, 128) │          0 │ stage2_block1_bn… │
# │ (Add)               │                   │            │ stage2_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu2 │ (None, 7, 7, 128) │          0 │ stage2_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv1 │ (None, 7, 7, 128) │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn1   │ (None, 7, 7, 128) │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu1 │ (None, 7, 7, 128) │          0 │ stage2_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv2 │ (None, 7, 7, 128) │    147,584 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn2   │ (None, 7, 7, 128) │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 7, 7, 128) │          0 │ stage2_block2_bn… │
# │ (Add)               │                   │            │ stage2_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu2 │ (None, 7, 7, 128) │          0 │ stage2_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv1 │ (None, 4, 4, 256) │    295,168 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn1   │ (None, 4, 4, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu1 │ (None, 4, 4, 256) │          0 │ stage3_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv2 │ (None, 4, 4, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 4, 4, 256) │     33,024 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn2   │ (None, 4, 4, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 4, 4, 256) │      1,024 │ stage3_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 4, 4, 256) │          0 │ stage3_block1_bn… │
# │ (Add)               │                   │            │ stage3_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu2 │ (None, 4, 4, 256) │          0 │ stage3_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv1 │ (None, 4, 4, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn1   │ (None, 4, 4, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu1 │ (None, 4, 4, 256) │          0 │ stage3_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv2 │ (None, 4, 4, 256) │    590,080 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn2   │ (None, 4, 4, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 4, 4, 256) │          0 │ stage3_block2_bn… │
# │ (Add)               │                   │            │ stage3_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu2 │ (None, 4, 4, 256) │          0 │ stage3_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv1 │ (None, 2, 2, 512) │  1,180,160 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn1   │ (None, 2, 2, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu1 │ (None, 2, 2, 512) │          0 │ stage4_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv2 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 2, 2, 512) │    131,584 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn2   │ (None, 2, 2, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 2, 2, 512) │      2,048 │ stage4_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 2, 2, 512) │          0 │ stage4_block1_bn… │
# │ (Add)               │                   │            │ stage4_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu2 │ (None, 2, 2, 512) │          0 │ stage4_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv1 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn1   │ (None, 2, 2, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu1 │ (None, 2, 2, 512) │          0 │ stage4_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv2 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn2   │ (None, 2, 2, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 2, 2, 512) │          0 │ stage4_block2_bn… │
# │ (Add)               │                   │            │ stage4_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu2 │ (None, 2, 2, 512) │          0 │ stage4_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ stage4_block2_re… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc (Dense)          │ (None, 2)         │      1,026 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,183,106 (42.66 MB)
#  Trainable params: 11,173,506 (42.62 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %% [markdown]
# ## Training

# %%
# Get callbacks
callbacks = get_callbacks(FINAL_MODEL_PATH, monitor=CHOSEN_METRIC, mode=MODE)

# Add dropout scheduler callback if using custom scheduler
if DROPOUT_MODE == "custom":
    dropout_scheduler = DropoutRateScheduler(dropout_start=DROPOUT_RATE_START, dropout_end=DROPOUT_RATE_END, epochs=EPOCHS)
    callbacks.append(dropout_scheduler)

# %%
# Train model
start_time = time.time()

history = model.fit(
        train_dataset,
        validation_data=(val_images, val_labels),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=tf_verbosity
    )

exec_time = round(time.time() - start_time, 2)
print(f"\nModel training completed in {exec_time} seconds")

# Save training info to logger
logger.add_training_info(history, exec_time)
# Out:
# Epoch 1: dropout rate set to 0.5000
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 40s 369ms/step - AUC: 0.8723 - accuracy: 0.7964 - loss: 0.5012 - val_AUC: 0.6875 - val_accuracy: 0.7424 - val_loss: 0.7241 - learning_rate: 0.0010
# Epoch 2: dropout rate set to 0.4980
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 134ms/step - AUC: 0.9598 - accuracy: 0.8901 - loss: 0.2433 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 3.6842 - learning_rate: 0.0010
# Epoch 3: dropout rate set to 0.4960
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - AUC: 0.9795 - accuracy: 0.9363 - loss: 0.1642 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 4.5565 - learning_rate: 0.0010
# Epoch 4: dropout rate set to 0.4940
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - AUC: 0.9601 - accuracy: 0.9040 - loss: 0.2389 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 7.0617 - learning_rate: 0.0010
# Epoch 5: dropout rate set to 0.4920
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - AUC: 0.9818 - accuracy: 0.9436 - loss: 0.1496 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 4.5459 - learning_rate: 0.0010
# Epoch 6: dropout rate set to 0.4900
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - AUC: 0.9823 - accuracy: 0.9452 - loss: 0.1536 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 3.2305 - learning_rate: 0.0010
# Epoch 7: dropout rate set to 0.4880
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - AUC: 0.9863 - accuracy: 0.9487 - loss: 0.1309 - val_AUC: 0.7580 - val_accuracy: 0.7424 - val_loss: 1.7355 - learning_rate: 2.0000e-04
# Epoch 8: dropout rate set to 0.4860
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - AUC: 0.9855 - accuracy: 0.9467 - loss: 0.1359 - val_AUC: 0.8526 - val_accuracy: 0.7863 - val_loss: 0.8482 - learning_rate: 2.0000e-04
# Epoch 9: dropout rate set to 0.4840
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - AUC: 0.9891 - accuracy: 0.9554 - loss: 0.1120 - val_AUC: 0.9396 - val_accuracy: 0.8798 - val_loss: 0.3318 - learning_rate: 2.0000e-04
# Epoch 10: dropout rate set to 0.4820
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - AUC: 0.9896 - accuracy: 0.9579 - loss: 0.1037 - val_AUC: 0.9885 - val_accuracy: 0.9695 - val_loss: 0.0952 - learning_rate: 2.0000e-04
# Epoch 11: dropout rate set to 0.4800
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - AUC: 0.9900 - accuracy: 0.9606 - loss: 0.0978 - val_AUC: 0.9916 - val_accuracy: 0.9618 - val_loss: 0.1016 - learning_rate: 2.0000e-04
# Epoch 12: dropout rate set to 0.4780
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - AUC: 0.9887 - accuracy: 0.9606 - loss: 0.1093 - val_AUC: 0.9951 - val_accuracy: 0.9695 - val_loss: 0.0810 - learning_rate: 2.0000e-04
# Epoch 13: dropout rate set to 0.4760
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - AUC: 0.9920 - accuracy: 0.9666 - loss: 0.0931 - val_AUC: 0.9912 - val_accuracy: 0.9676 - val_loss: 0.0855 - learning_rate: 2.0000e-04
# Epoch 14: dropout rate set to 0.4740
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - AUC: 0.9893 - accuracy: 0.9607 - loss: 0.1055 - val_AUC: 0.9641 - val_accuracy: 0.9084 - val_loss: 0.2171 - learning_rate: 2.0000e-04
# Epoch 15: dropout rate set to 0.4720
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - AUC: 0.9910 - accuracy: 0.9601 - loss: 0.0969 - val_AUC: 0.9872 - val_accuracy: 0.9504 - val_loss: 0.1129 - learning_rate: 2.0000e-04
# Epoch 16: dropout rate set to 0.4700
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - AUC: 0.9888 - accuracy: 0.9664 - loss: 0.1017 - val_AUC: 0.9552 - val_accuracy: 0.9122 - val_loss: 0.2263 - learning_rate: 2.0000e-04
# Epoch 17: dropout rate set to 0.4680
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - AUC: 0.9912 - accuracy: 0.9653 - loss: 0.0950 - val_AUC: 0.9925 - val_accuracy: 0.9637 - val_loss: 0.0897 - learning_rate: 2.0000e-04
# Epoch 18: dropout rate set to 0.4660
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - AUC: 0.9941 - accuracy: 0.9685 - loss: 0.0831 - val_AUC: 0.9894 - val_accuracy: 0.9542 - val_loss: 0.1049 - learning_rate: 4.0000e-05
# Epoch 19: dropout rate set to 0.4640
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - AUC: 0.9919 - accuracy: 0.9690 - loss: 0.0842 - val_AUC: 0.9952 - val_accuracy: 0.9676 - val_loss: 0.0977 - learning_rate: 4.0000e-05
# Epoch 20: dropout rate set to 0.4620
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - AUC: 0.9941 - accuracy: 0.9719 - loss: 0.0736 - val_AUC: 0.9948 - val_accuracy: 0.9580 - val_loss: 0.0986 - learning_rate: 4.0000e-05
# Epoch 21: dropout rate set to 0.4600
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - AUC: 0.9926 - accuracy: 0.9716 - loss: 0.0812 - val_AUC: 0.9918 - val_accuracy: 0.9580 - val_loss: 0.0942 - learning_rate: 4.0000e-05
# Epoch 22: dropout rate set to 0.4580
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - AUC: 0.9936 - accuracy: 0.9712 - loss: 0.0790 - val_AUC: 0.9914 - val_accuracy: 0.9466 - val_loss: 0.1130 - learning_rate: 4.0000e-05
# Epoch 23: dropout rate set to 0.4560
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - AUC: 0.9925 - accuracy: 0.9706 - loss: 0.0814 - val_AUC: 0.9917 - val_accuracy: 0.9599 - val_loss: 0.0965 - learning_rate: 8.0000e-06
# Epoch 24: dropout rate set to 0.4540
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - AUC: 0.9940 - accuracy: 0.9672 - loss: 0.0781 - val_AUC: 0.9935 - val_accuracy: 0.9599 - val_loss: 0.0940 - learning_rate: 8.0000e-06
# Epoch 25: dropout rate set to 0.4520
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - AUC: 0.9923 - accuracy: 0.9721 - loss: 0.0806 - val_AUC: 0.9926 - val_accuracy: 0.9542 - val_loss: 0.1027 - learning_rate: 8.0000e-06
# Epoch 26: dropout rate set to 0.4500
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - AUC: 0.9955 - accuracy: 0.9778 - loss: 0.0653 - val_AUC: 0.9936 - val_accuracy: 0.9599 - val_loss: 0.0941 - learning_rate: 8.0000e-06
# Epoch 27: dropout rate set to 0.4480
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - AUC: 0.9935 - accuracy: 0.9724 - loss: 0.0733 - val_AUC: 0.9933 - val_accuracy: 0.9599 - val_loss: 0.0943 - learning_rate: 8.0000e-06
# Epoch 28: dropout rate set to 0.4460
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - AUC: 0.9932 - accuracy: 0.9702 - loss: 0.0801 - val_AUC: 0.9935 - val_accuracy: 0.9599 - val_loss: 0.0933 - learning_rate: 1.6000e-06
# Epoch 29: dropout rate set to 0.4440
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - AUC: 0.9953 - accuracy: 0.9753 - loss: 0.0680 - val_AUC: 0.9933 - val_accuracy: 0.9599 - val_loss: 0.0939 - learning_rate: 1.6000e-06
#
# Model training completed in 283.89 seconds

# %%
# Plot training history
plot_training_history(history)

# %% [markdown]
# ## Evaluation

# %%
# Evaluate model with reduced verbosity
results = evaluate_model(model, test_images, test_labels, verbose=tf_verbosity)

# Add evaluation results to logger
logger.add_evaluation_results(results)

# Plot results
plot_roc_curve(results['roc']['fpr'], results['roc']['tpr'], results['roc']['auc'])
plot_confusion_matrix(results['confusion_matrix'])
print(results['classification_report'])
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - AUC: 0.9324 - accuracy: 0.8666 - loss: 0.3298
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step
# ROC AUC Score: 0.971707
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.68      0.80       234
#    Pneumonia       0.84      0.98      0.90       390
#
#     accuracy                           0.87       624
#    macro avg       0.90      0.83      0.85       624
# weighted avg       0.88      0.87      0.86       624

# %% [markdown]
# ## Checkpointing

# %%
# Save all model information
logger.save(LOG_PATH)

# Save final model
model.save(FINAL_MODEL_PATH)
print(f"Model saved to {FINAL_MODEL_PATH}")
# Out:
# Run information saved to ../output/logs/resnet_18_augmented_info.json
# Model saved to ../output/models/resnet_18_augmented_b96_lr0.001_dr0.5_0.3_pneumonia_model.keras
