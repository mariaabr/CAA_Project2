# %% [markdown]
# # CAA Project - Deep Learning Approaches for Pneumonia Detection: A Comparative Study on Chest X-Ray Images
#
# **ResNet-18 Augmented Models Notebook**
#
# **Description:** This is the Jupyter Notebook training and evaluating a ResNet-18 model on the Pneumonia dataset with data augmentation.
#
# Authors:
# - Rafaela Abrunhosa, 107658
# - Miguel Pinto, 107449

# %% [markdown]
# # External Libraries

# %%
# Import utility libraries
import sys
sys.path.append('..')  # Add parent directory to path to allow import of custom modules

# Import deep learning libraries
import tensorflow as tf

# Import custom utilities
from utils.data_utils import load_and_preprocess_data
from utils.model.resnet_utils import build_resnet18, DropoutRateScheduler
from utils.train_utils import get_callbacks
from utils.eval_utils import evaluate_model, compare_models
from utils.plot_utils import plot_training_history, plot_roc_curve, plot_confusion_matrix
# Out:
# 2025-03-20 14:22:35.758006: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-20 14:22:35.870565: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742480555.917364    5125 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742480555.931020    5125 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-20 14:22:36.036894: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Core Variables

# %%
# Global variables
DATA_PATH = '../data/'
MODEL_PATH = '../models/'
MODEL_NAME = 'resnet_18_augmented' # Name of the model to be saved
BEST_MODEL_PATH = f'{MODEL_PATH}{MODEL_NAME}_best_model.keras'
FINAL_MODEL_PATH = f'{MODEL_PATH}{MODEL_NAME}_pneumonia_model.keras'

# Training parameters
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001
DROPOUT_RATE = 0.3
CHOSEN_METRIC = 'val_AUC' # Metric to be used for model selection, e.g. 'val_loss', 'val_AUC', 'val_accuracy'

# %% [markdown]
# # Data Loading & Preprocessing

# %%
train_dataset, (test_images, test_labels), (val_images, val_labels) = load_and_preprocess_data(
        DATA_PATH, 
        augment=True, 
        batch_size=BATCH_SIZE
    )
# Out:
# Dataset shapes - Original:
# Train - images: (4708, 28, 28)  labels: (4708, 1)
# Val   - images: (524, 28, 28)  labels: (524, 1)
# Test  - images: (624, 28, 28)  labels: (624, 1)
#
# Dataset shapes - After preprocessing:
# Train images shape: (4708, 28, 28, 1)
# Train labels shape: (4708, 2)
# Val images shape: (524, 28, 28, 1)
# Val labels shape: (524, 2)
# Test images shape: (624, 28, 28, 1)
# Test labels shape: (624, 2)
#
# Applying data augmentation to training data...
# I0000 00:00:1742480560.641092    5125 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2787 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# # ResNet-18 Model

# %% [markdown]
# ## Creation & Compilation

# %%
# Create and compile model
model = build_resnet18(dropout_rate=DROPOUT_RATE)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 'AUC']
)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 28, 28,    │        640 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 28, 28,    │        256 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, 28, 28,    │          0 │ bn1[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 14, 14,    │          0 │ relu1[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv1 │ (None, 14, 14,    │     36,928 │ maxpool1[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn1   │ (None, 14, 14,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu1 │ (None, 14, 14,    │          0 │ stage1_block1_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv2 │ (None, 14, 14,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn2   │ (None, 14, 14,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_add   │ (None, 14, 14,    │          0 │ stage1_block1_bn… │
# │ (Add)               │ 64)               │            │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu2 │ (None, 14, 14,    │          0 │ stage1_block1_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv1 │ (None, 14, 14,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn1   │ (None, 14, 14,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu1 │ (None, 14, 14,    │          0 │ stage1_block2_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv2 │ (None, 14, 14,    │     36,928 │ stage1_block2_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn2   │ (None, 14, 14,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_add   │ (None, 14, 14,    │          0 │ stage1_block2_bn… │
# │ (Add)               │ 64)               │            │ stage1_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu2 │ (None, 14, 14,    │          0 │ stage1_block2_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv1 │ (None, 7, 7, 128) │     73,856 │ stage1_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn1   │ (None, 7, 7, 128) │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu1 │ (None, 7, 7, 128) │          0 │ stage2_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv2 │ (None, 7, 7, 128) │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 7, 7, 128) │      8,320 │ stage1_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn2   │ (None, 7, 7, 128) │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 7, 7, 128) │        512 │ stage2_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 7, 7, 128) │          0 │ stage2_block1_bn… │
# │ (Add)               │                   │            │ stage2_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu2 │ (None, 7, 7, 128) │          0 │ stage2_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv1 │ (None, 7, 7, 128) │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn1   │ (None, 7, 7, 128) │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu1 │ (None, 7, 7, 128) │          0 │ stage2_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv2 │ (None, 7, 7, 128) │    147,584 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn2   │ (None, 7, 7, 128) │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 7, 7, 128) │          0 │ stage2_block2_bn… │
# │ (Add)               │                   │            │ stage2_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu2 │ (None, 7, 7, 128) │          0 │ stage2_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv1 │ (None, 4, 4, 256) │    295,168 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn1   │ (None, 4, 4, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu1 │ (None, 4, 4, 256) │          0 │ stage3_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv2 │ (None, 4, 4, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 4, 4, 256) │     33,024 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn2   │ (None, 4, 4, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 4, 4, 256) │      1,024 │ stage3_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 4, 4, 256) │          0 │ stage3_block1_bn… │
# │ (Add)               │                   │            │ stage3_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu2 │ (None, 4, 4, 256) │          0 │ stage3_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv1 │ (None, 4, 4, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn1   │ (None, 4, 4, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu1 │ (None, 4, 4, 256) │          0 │ stage3_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv2 │ (None, 4, 4, 256) │    590,080 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn2   │ (None, 4, 4, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 4, 4, 256) │          0 │ stage3_block2_bn… │
# │ (Add)               │                   │            │ stage3_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu2 │ (None, 4, 4, 256) │          0 │ stage3_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv1 │ (None, 2, 2, 512) │  1,180,160 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn1   │ (None, 2, 2, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu1 │ (None, 2, 2, 512) │          0 │ stage4_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv2 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 2, 2, 512) │    131,584 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn2   │ (None, 2, 2, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 2, 2, 512) │      2,048 │ stage4_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 2, 2, 512) │          0 │ stage4_block1_bn… │
# │ (Add)               │                   │            │ stage4_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu2 │ (None, 2, 2, 512) │          0 │ stage4_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv1 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn1   │ (None, 2, 2, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu1 │ (None, 2, 2, 512) │          0 │ stage4_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv2 │ (None, 2, 2, 512) │  2,359,808 │ stage4_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn2   │ (None, 2, 2, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 2, 2, 512) │          0 │ stage4_block2_bn… │
# │ (Add)               │                   │            │ stage4_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu2 │ (None, 2, 2, 512) │          0 │ stage4_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ stage4_block2_re… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc (Dense)          │ (None, 2)         │      1,026 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,183,106 (42.66 MB)
#  Trainable params: 11,173,506 (42.62 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %% [markdown]
# ## Callback Definition

# %%
# Get callbacks
callbacks = get_callbacks(BEST_MODEL_PATH, monitor=CHOSEN_METRIC, mode='max')
dropout_scheduler = DropoutRateScheduler(dropout_start=0.5, dropout_end=0.3, epochs=EPOCHS)
callbacks.append(dropout_scheduler)

# %% [markdown]
# ## Training

# %%
# Train model
history = model.fit(
        train_dataset,
        validation_data=(val_images, val_labels),
        epochs=EPOCHS,
        callbacks=callbacks
    )

# Plot training history
plot_training_history(history)

# Save final model
model.save(FINAL_MODEL_PATH)
# Out:
# Epoch 1: dropout rate set to 0.5000
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742480569.839019    5199 service.cc:148] XLA service 0x712360003ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742480569.839169    5199 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti with Max-Q Design, Compute Capability 7.5
# 2025-03-20 14:22:50.134248: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742480571.277458    5199 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-20 14:22:52.228786: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:22:52.441094: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,7,7]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:22:52.650116: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,4,4]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:22:53.450613: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[256,32,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,512,6,6]{3,2,1,0}, f32[32,512,3,3]{3,2,1,0}, f32[32]{0}, f32[256,32,4,4]{3,2,1,0}), window={size=3x3 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:22:56.236425: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:930] The NVIDIA driver's CUDA version is 12.4 which is older than the PTX compiler version 12.5.82. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   3/148 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - AUC: 0.5386 - accuracy: 0.5226 - loss: 1.5034
# I0000 00:00:1742480579.794144    5199 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 146/148 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - AUC: 0.8988 - accuracy: 0.8325 - loss: 0.5611
# 2025-03-20 14:23:08.093362: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[4,64,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:23:08.188476: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[4,128,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,128,7,7]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:23:08.369158: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[4,256,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,256,4,4]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:23:08.880191: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[256,4,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,512,6,6]{3,2,1,0}, f32[4,512,3,3]{3,2,1,0}, f32[4]{0}, f32[256,4,4,4]{3,2,1,0}), window={size=3x3 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - AUC: 0.8992 - accuracy: 0.8330 - loss: 0.5595
# 2025-03-20 14:23:17.534991: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,64,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:23:17.667312: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,128,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,128,7,7]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:23:17.824198: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,256,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,256,4,4]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 38s 136ms/step - AUC: 0.8994 - accuracy: 0.8332 - loss: 0.5586 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 1.9679 - learning_rate: 0.0010
# Epoch 2: dropout rate set to 0.4960
# Epoch 2/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9613 - accuracy: 0.8950 - loss: 0.2811 - val_AUC: 0.7424 - val_accuracy: 0.7424 - val_loss: 2.6444 - learning_rate: 0.0010
# Epoch 3: dropout rate set to 0.4920
# Epoch 3/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - AUC: 0.9737 - accuracy: 0.9150 - loss: 0.2121 - val_AUC: 0.8803 - val_accuracy: 0.7634 - val_loss: 1.0606 - learning_rate: 0.0010
# Epoch 4: dropout rate set to 0.4880
# Epoch 4/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - AUC: 0.9783 - accuracy: 0.9195 - loss: 0.1890 - val_AUC: 0.9581 - val_accuracy: 0.8779 - val_loss: 0.2808 - learning_rate: 0.0010
# Epoch 5: dropout rate set to 0.4840
# Epoch 5/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - AUC: 0.9821 - accuracy: 0.9294 - loss: 0.1683 - val_AUC: 0.9750 - val_accuracy: 0.9027 - val_loss: 0.2022 - learning_rate: 0.0010
# Epoch 6: dropout rate set to 0.4800
# Epoch 6/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - AUC: 0.9816 - accuracy: 0.9378 - loss: 0.1703 - val_AUC: 0.9925 - val_accuracy: 0.9618 - val_loss: 0.1095 - learning_rate: 0.0010
# Epoch 7: dropout rate set to 0.4760
# Epoch 7/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9853 - accuracy: 0.9422 - loss: 0.1511 - val_AUC: 0.9594 - val_accuracy: 0.9065 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 8: dropout rate set to 0.4720
# Epoch 8/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9868 - accuracy: 0.9417 - loss: 0.1440 - val_AUC: 0.9881 - val_accuracy: 0.9618 - val_loss: 0.1322 - learning_rate: 0.0010
# Epoch 9: dropout rate set to 0.4680
# Epoch 9/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9891 - accuracy: 0.9475 - loss: 0.1314 - val_AUC: 0.9873 - val_accuracy: 0.9580 - val_loss: 0.1456 - learning_rate: 0.0010
# Epoch 10: dropout rate set to 0.4640
# Epoch 10/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - AUC: 0.9882 - accuracy: 0.9461 - loss: 0.1377 - val_AUC: 0.9940 - val_accuracy: 0.9599 - val_loss: 0.1081 - learning_rate: 0.0010
# Epoch 11: dropout rate set to 0.4600
# Epoch 11/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9883 - accuracy: 0.9461 - loss: 0.1372 - val_AUC: 0.9277 - val_accuracy: 0.7882 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 12: dropout rate set to 0.4560
# Epoch 12/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9895 - accuracy: 0.9507 - loss: 0.1292 - val_AUC: 0.9785 - val_accuracy: 0.9198 - val_loss: 0.1985 - learning_rate: 0.0010
# Epoch 13: dropout rate set to 0.4520
# Epoch 13/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9899 - accuracy: 0.9591 - loss: 0.1233 - val_AUC: 0.9301 - val_accuracy: 0.7939 - val_loss: 0.4907 - learning_rate: 0.0010
# Epoch 14: dropout rate set to 0.4480
# Epoch 14/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9895 - accuracy: 0.9544 - loss: 0.1282 - val_AUC: 0.9910 - val_accuracy: 0.9523 - val_loss: 0.1219 - learning_rate: 0.0010
# Epoch 15: dropout rate set to 0.4440
# Epoch 15/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9906 - accuracy: 0.9543 - loss: 0.1193 - val_AUC: 0.9878 - val_accuracy: 0.9370 - val_loss: 0.1512 - learning_rate: 0.0010
# Epoch 16: dropout rate set to 0.4400
# Epoch 16/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - AUC: 0.9924 - accuracy: 0.9627 - loss: 0.1078 - val_AUC: 0.9972 - val_accuracy: 0.9656 - val_loss: 0.0733 - learning_rate: 2.0000e-04
# Epoch 17: dropout rate set to 0.4360
# Epoch 17/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9931 - accuracy: 0.9612 - loss: 0.1006 - val_AUC: 0.9968 - val_accuracy: 0.9733 - val_loss: 0.0762 - learning_rate: 2.0000e-04
# Epoch 18: dropout rate set to 0.4320
# Epoch 18/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - AUC: 0.9948 - accuracy: 0.9653 - loss: 0.0891 - val_AUC: 0.9942 - val_accuracy: 0.9504 - val_loss: 0.0988 - learning_rate: 2.0000e-04
# Epoch 19: dropout rate set to 0.4280
# Epoch 19/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - AUC: 0.9928 - accuracy: 0.9639 - loss: 0.1032 - val_AUC: 0.9951 - val_accuracy: 0.9676 - val_loss: 0.0895 - learning_rate: 2.0000e-04
# Epoch 20: dropout rate set to 0.4240
# Epoch 20/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - AUC: 0.9948 - accuracy: 0.9685 - loss: 0.0827 - val_AUC: 0.9974 - val_accuracy: 0.9733 - val_loss: 0.0670 - learning_rate: 2.0000e-04
# Epoch 21: dropout rate set to 0.4200
# Epoch 21/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - AUC: 0.9950 - accuracy: 0.9695 - loss: 0.0854 - val_AUC: 0.9611 - val_accuracy: 0.8645 - val_loss: 0.3154 - learning_rate: 2.0000e-04
# Epoch 22: dropout rate set to 0.4160
# Epoch 22/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9951 - accuracy: 0.9693 - loss: 0.0857 - val_AUC: 0.9888 - val_accuracy: 0.9447 - val_loss: 0.1391 - learning_rate: 2.0000e-04
# Epoch 23: dropout rate set to 0.4120
# Epoch 23/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9960 - accuracy: 0.9664 - loss: 0.0809 - val_AUC: 0.9971 - val_accuracy: 0.9771 - val_loss: 0.0711 - learning_rate: 2.0000e-04
# Epoch 24: dropout rate set to 0.4080
# Epoch 24/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9953 - accuracy: 0.9715 - loss: 0.0803 - val_AUC: 0.9968 - val_accuracy: 0.9809 - val_loss: 0.0718 - learning_rate: 2.0000e-04
# Epoch 25: dropout rate set to 0.4040
# Epoch 25/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9945 - accuracy: 0.9695 - loss: 0.0853 - val_AUC: 0.9925 - val_accuracy: 0.9504 - val_loss: 0.1133 - learning_rate: 2.0000e-04
# Epoch 26: dropout rate set to 0.4000
# Epoch 26/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9967 - accuracy: 0.9711 - loss: 0.0658 - val_AUC: 0.9951 - val_accuracy: 0.9580 - val_loss: 0.0888 - learning_rate: 4.0000e-05
# Epoch 27: dropout rate set to 0.3960
# Epoch 27/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9964 - accuracy: 0.9752 - loss: 0.0690 - val_AUC: 0.9953 - val_accuracy: 0.9637 - val_loss: 0.0875 - learning_rate: 4.0000e-05
# Epoch 28: dropout rate set to 0.3920
# Epoch 28/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9969 - accuracy: 0.9820 - loss: 0.0570 - val_AUC: 0.9958 - val_accuracy: 0.9695 - val_loss: 0.0831 - learning_rate: 4.0000e-05
# Epoch 29: dropout rate set to 0.3880
# Epoch 29/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9973 - accuracy: 0.9770 - loss: 0.0637 - val_AUC: 0.9946 - val_accuracy: 0.9637 - val_loss: 0.0926 - learning_rate: 4.0000e-05
# Epoch 30: dropout rate set to 0.3840
# Epoch 30/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - AUC: 0.9962 - accuracy: 0.9783 - loss: 0.0634 - val_AUC: 0.9961 - val_accuracy: 0.9695 - val_loss: 0.0804 - learning_rate: 4.0000e-05

# %% [markdown]
# ## Evaluation

# %%
# Evaluate model
results = evaluate_model(model, test_images, test_labels)

# Plot results
plot_roc_curve(results['roc']['fpr'], results['roc']['tpr'], results['roc']['auc'])
plot_confusion_matrix(results['confusion_matrix'])
print(results['classification_report'])
# Out:
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.9424 - accuracy: 0.8723 - loss: 0.3916
# 2025-03-20 14:26:49.544566: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:26:49.660427: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,7,7]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-20 14:26:49.837020: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,4,4]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - AUC: 0.9428 - accuracy: 0.8726 - loss: 0.3901
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# ROC AUC Score: 0.9730
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.68      0.80       234
#    Pneumonia       0.84      0.99      0.91       390
#
#     accuracy                           0.88       624
#    macro avg       0.91      0.84      0.86       624
# weighted avg       0.89      0.88      0.87       624

# %% [markdown]
# ### Comparison

# %%
# Load best model from training
best_model = tf.keras.models.load_model(BEST_MODEL_PATH)

# Compare with final model
results_best, results_final = compare_models(best_model, model, test_images, test_labels)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - AUC: 0.9428 - accuracy: 0.8726 - loss: 0.3901
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9428 - accuracy: 0.8726 - loss: 0.3901
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Best Model (in Training) vs Selected Model (through callbacks):
# Test accuracy: 0.875000 vs 0.875000
# Test AUC: 0.972978 vs 0.972978
