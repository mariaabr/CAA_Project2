# %% [markdown]
# # Deep Learning Architectures for Pneumonia Detection: Multi-Scale Analysis with Explainable AI
#
# **ResNet18 Fine-Tuned Models Notebook**
#
# **Description:** This notebook fine-tunes the best performing ResNet18 model on higher resolution images (64x64) to improve performance for subsequent XAI analysis.
#
# Authors:
# - Rafaela Abrunhosa, 107658
# - Miguel Pinto, 107449

# %% [markdown]
# # External Libraries

# %%
# Import utility libraries
import os
import sys
import time
from datetime import datetime
sys.path.append('..')  # Add parent directory to path to allow import of custom modules

# Import deep learning libraries
import tensorflow as tf

# Suppress TensorFlow warnings
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # 0=all, 1=info, 2=warning, 3=error
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'   # Disable oneDNN optimizations for reproducibility

# Disable verbose output from TensorFlow during training
tf_verbosity = 1  # 0 = silent, 1 = progress bar, 2 = one line per epoch

# Import custom utilities
from utils.data_utils import load_and_preprocess_multiscale_data
from utils.finetune_utils import (
    load_pretrained_model, extract_model_params,
    freeze_layers, generate_tuned_model_path
)
from utils.model.resnet_utils import adapt_resnet18_for_resolution, transfer_resnet18_weights
from utils.train_utils import get_callbacks
from utils.eval_utils import evaluate_model
from utils.plot_utils import plot_training_history, plot_roc_curve, plot_confusion_matrix
from utils.logger_utils import ModelLogger
# Out:
# 2025-06-19 22:06:50.011411: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-19 22:06:50.027608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750367210.048025   60289 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750367210.053297   60289 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-19 22:06:50.072554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Core Variables

# %%
# Global seed for reproducibility
RANDOM_SEED = 42

# Architecture and paths
ARCHITECTURE = 'resnet_18'                # Architecture name
DATA_PATH = '../data/'                    # Path to the dataset
OUTPUT_PATH = '../output/'                # Path to save output files
MODEL_PATH = OUTPUT_PATH + 'models/'      # Path to save models
LOG_PATH = OUTPUT_PATH + 'logs/'          # Path to save logs

# Fine-tuning parameters
ORIGINAL_SIZE = 28                        # Original training image size
TARGET_SIZE = 64                          # Target fine-tuning image size
FINE_TUNE_LR = 0.0001                     # Lower learning rate for fine-tuning (10x reduction)
FINE_TUNE_EPOCHS = 30                     # Number of fine-tuning epochs

# Architecture-specific freeze ratios
# These ratios determine what percentage of layers to freeze during fine-tuning:
# - Higher ratio = more frozen layers = preserves more pre-trained features
# - Lower ratio = fewer frozen layers = allows more adaptation to new resolution
FREEZE_RATIOS = {
    'alexnet': 0.85,      # AlexNet: 85% - with 29 layers, this gives ~25 frozen, 4 trainable
    'resnet_18': 0.60,    # ResNet18: 60% - lower due to residual connections
    'resnet_50': 0.80,    # ResNet50: 80% - higher due to depth (50 layers)
    'densenet_169': 0.75  # DenseNet169: 75% - dense connections benefit from more frozen early layers
}

FREEZE_RATIO = FREEZE_RATIOS[ARCHITECTURE]
print(f"Using freeze ratio for {ARCHITECTURE}: {FREEZE_RATIO*100:.0f}%")

# Ensure directories exist
os.makedirs(MODEL_PATH, exist_ok=True)
os.makedirs(LOG_PATH, exist_ok=True)
# Out:
# Using freeze ratio for resnet18: 60%

# %% [markdown]
# # Load Best Pre-trained Model

# %%
# Load the specified pre-trained model
MODEL_FILENAME = 'resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras'
best_model_path = os.path.join(MODEL_PATH, MODEL_FILENAME)

print(f"Loading pre-trained model: {best_model_path}")
pretrained_model = load_pretrained_model(best_model_path)
print(f"✓ Loaded model with {pretrained_model.count_params():,} parameters")

# Extract parameters from the model filename
original_params = extract_model_params(MODEL_FILENAME)
print("Parameters extracted from model filename:")
for key, value in original_params.items():
    print(f"  {key}: {value}")
# Out:
# Loading pre-trained model: ../output/models/resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras
# Loading model from: ../output/models/resnet_18_augmented_b64_lr0.001_dr0.5_pneumonia_model.keras
# I0000 00:00:1750367213.719665   60289 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2787 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model loaded successfully: functional_3
# ✓ Loaded model with 11,183,106 parameters
# Parameters extracted from model filename:
#   batch_size: 64
#   learning_rate: 0.001
#   dropout_rate: 0.5
#   augmented: True
#   dropout_mode: fixed

# %% [markdown]
# # Data Loading & Preprocessing

# %%
# Load data with target resolution
print(f"Loading data with {TARGET_SIZE}x{TARGET_SIZE} resolution...")
train_dataset, (test_images, test_labels), (val_images, val_labels) = load_and_preprocess_multiscale_data(
    DATA_PATH,
    image_size=TARGET_SIZE,
    augment=original_params['augmented'],  # Use same augmentation as original model
    batch_size=original_params['batch_size'],
    seed=RANDOM_SEED
)
print(f"✓ Data loaded successfully")
# Out:
# Loading data with 64x64 resolution...
#
# Dataset shapes - 64x64 resolution:
# Train - images: (4708, 64, 64)  labels: (4708, 1)
# Val   - images: (524, 64, 64)  labels: (524, 1)
# Test  - images: (624, 64, 64)  labels: (624, 1)
#
# Dataset loaded with augmentation: True
# Batch size: 64
#
# Dataset loaded with augmentation: True
# Batch size: 64

# %% [markdown]
# # Model Adaptation & Fine-tuning Setup

# %%
# Adapt the ResNet18 model for the new resolution
print(f"\nAdapting ResNet18 from {ORIGINAL_SIZE}x{ORIGINAL_SIZE} to {TARGET_SIZE}x{TARGET_SIZE}...")

adapted_model = adapt_resnet18_for_resolution(
    pretrained_model, 
    TARGET_SIZE, 
    dropout_rate=original_params['dropout_rate']
)

print(f"✓ ResNet18 successfully adapted from {ORIGINAL_SIZE}x{ORIGINAL_SIZE} to {TARGET_SIZE}x{TARGET_SIZE}")

# Transfer weights from the original model to the adapted model
print("Transferring compatible weights...")
adapted_model = transfer_resnet18_weights(pretrained_model, adapted_model)

# Freeze layers for fine-tuning
print(f"\nApplying freeze ratio of {FREEZE_RATIO*100:.0f}%...")
adapted_model = freeze_layers(adapted_model, freeze_ratio=FREEZE_RATIO)

print(f"\nModel setup complete for fine-tuning:")
print(f"  Architecture: ResNet18")
print(f"  Original resolution: {ORIGINAL_SIZE}x{ORIGINAL_SIZE}")
print(f"  Target resolution: {TARGET_SIZE}x{TARGET_SIZE}")
print(f"  Freeze ratio: {FREEZE_RATIO*100:.0f}%")

adapted_model.summary()
# Out:
# Adapting ResNet18 from 28x28 to 64x64...
# Building new ResNet18 for 64x64 resolution...
# Using dropout rate: 0.5
# ✓ ResNet18 successfully adapted from (None, 28, 28, 1) to (64, 64, 1)
# Original parameters: 11,183,106
# Adapted parameters: 11,183,106
# ✓ ResNet18 successfully adapted from 28x28 to 64x64
# Transferring compatible weights...
#
# Transferring ResNet18 weights...
# ✓ Conv2D layer conv1: 64 filters
# ✓ BatchNorm layer bn1
# ✓ Conv2D layer stage1_block1_conv1: 64 filters
# ✓ BatchNorm layer stage1_block1_bn1
# ✓ Conv2D layer stage1_block1_conv2: 64 filters
# ✓ BatchNorm layer stage1_block1_bn2
# ✓ Conv2D layer stage1_block2_conv1: 64 filters
# ✓ BatchNorm layer stage1_block2_bn1
# ✓ Conv2D layer stage1_block2_conv2: 64 filters
# ✓ BatchNorm layer stage1_block2_bn2
# ✓ Conv2D layer stage2_block1_conv1: 128 filters
# ✓ BatchNorm layer stage2_block1_bn1
# ✓ Conv2D layer stage2_block1_conv2: 128 filters
# ✓ Conv2D layer stage2_block1_shortcut_conv: 128 filters
# ✓ BatchNorm layer stage2_block1_bn2
# ✓ BatchNorm layer stage2_block1_shortcut_bn
# ✓ Conv2D layer stage2_block2_conv1: 128 filters
# ✓ BatchNorm layer stage2_block2_bn1
# ✓ Conv2D layer stage2_block2_conv2: 128 filters
# ✓ BatchNorm layer stage2_block2_bn2
# ✓ Conv2D layer stage3_block1_conv1: 256 filters
# ✓ BatchNorm layer stage3_block1_bn1
# ✓ Conv2D layer stage3_block1_conv2: 256 filters
# ✓ Conv2D layer stage3_block1_shortcut_conv: 256 filters
# ✓ BatchNorm layer stage3_block1_bn2
# ✓ BatchNorm layer stage3_block1_shortcut_bn
# ✓ Conv2D layer stage3_block2_conv1: 256 filters
# ✓ BatchNorm layer stage3_block2_bn1
# ✓ Conv2D layer stage3_block2_conv2: 256 filters
# ✓ BatchNorm layer stage3_block2_bn2
# ✓ Conv2D layer stage4_block1_conv1: 512 filters
# ✓ BatchNorm layer stage4_block1_bn1
# ✓ Conv2D layer stage4_block1_conv2: 512 filters
# ✓ Conv2D layer stage4_block1_shortcut_conv: 512 filters
# ✓ BatchNorm layer stage4_block1_bn2
# ✓ BatchNorm layer stage4_block1_shortcut_bn
# ✓ ResNet18 successfully adapted from (None, 28, 28, 1) to (64, 64, 1)
# Original parameters: 11,183,106
# Adapted parameters: 11,183,106
# ✓ ResNet18 successfully adapted from 28x28 to 64x64
# Transferring compatible weights...
#
# Transferring ResNet18 weights...
# ✓ Conv2D layer conv1: 64 filters
# ✓ BatchNorm layer bn1
# ✓ Conv2D layer stage1_block1_conv1: 64 filters
# ✓ BatchNorm layer stage1_block1_bn1
# ✓ Conv2D layer stage1_block1_conv2: 64 filters
# ✓ BatchNorm layer stage1_block1_bn2
# ✓ Conv2D layer stage1_block2_conv1: 64 filters
# ✓ BatchNorm layer stage1_block2_bn1
# ✓ Conv2D layer stage1_block2_conv2: 64 filters
# ✓ BatchNorm layer stage1_block2_bn2
# ✓ Conv2D layer stage2_block1_conv1: 128 filters
# ✓ BatchNorm layer stage2_block1_bn1
# ✓ Conv2D layer stage2_block1_conv2: 128 filters
# ✓ Conv2D layer stage2_block1_shortcut_conv: 128 filters
# ✓ BatchNorm layer stage2_block1_bn2
# ✓ BatchNorm layer stage2_block1_shortcut_bn
# ✓ Conv2D layer stage2_block2_conv1: 128 filters
# ✓ BatchNorm layer stage2_block2_bn1
# ✓ Conv2D layer stage2_block2_conv2: 128 filters
# ✓ BatchNorm layer stage2_block2_bn2
# ✓ Conv2D layer stage3_block1_conv1: 256 filters
# ✓ BatchNorm layer stage3_block1_bn1
# ✓ Conv2D layer stage3_block1_conv2: 256 filters
# ✓ Conv2D layer stage3_block1_shortcut_conv: 256 filters
# ✓ BatchNorm layer stage3_block1_bn2
# ✓ BatchNorm layer stage3_block1_shortcut_bn
# ✓ Conv2D layer stage3_block2_conv1: 256 filters
# ✓ BatchNorm layer stage3_block2_bn1
# ✓ Conv2D layer stage3_block2_conv2: 256 filters
# ✓ BatchNorm layer stage3_block2_bn2
# ✓ Conv2D layer stage4_block1_conv1: 512 filters
# ✓ BatchNorm layer stage4_block1_bn1
# ✓ Conv2D layer stage4_block1_conv2: 512 filters
# ✓ Conv2D layer stage4_block1_shortcut_conv: 512 filters
# ✓ BatchNorm layer stage4_block1_bn2
# ✓ BatchNorm layer stage4_block1_shortcut_bn
# ✓ Conv2D layer stage4_block2_conv1: 512 filters
# ✓ BatchNorm layer stage4_block2_bn1
# ✓ Conv2D layer stage4_block2_conv2: 512 filters
# ✓ BatchNorm layer stage4_block2_bn2
# ✓ Dense layer fc: 2 units
#
# ResNet18 weight transfer complete: 41 layers transferred
#
# Applying freeze ratio of 60%...
# Frozen layers: 42
# Trainable layers: 28
#
# Model setup complete for fine-tuning:
#   Architecture: ResNet18
#   Original resolution: 28x28
#   Target resolution: 64x64
#   Freeze ratio: 60%
# ✓ Conv2D layer stage4_block2_conv1: 512 filters
# ✓ BatchNorm layer stage4_block2_bn1
# ✓ Conv2D layer stage4_block2_conv2: 512 filters
# ✓ BatchNorm layer stage4_block2_bn2
# ✓ Dense layer fc: 2 units
#
# ResNet18 weight transfer complete: 41 layers transferred
#
# Applying freeze ratio of 60%...
# Frozen layers: 42
# Trainable layers: 28
#
# Model setup complete for fine-tuning:
#   Architecture: ResNet18
#   Original resolution: 28x28
#   Target resolution: 64x64
#   Freeze ratio: 60%
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 64, 64,    │        640 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 64, 64,    │        256 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, 64, 64,    │          0 │ bn1[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 32, 32,    │          0 │ relu1[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv1 │ (None, 32, 32,    │     36,928 │ maxpool1[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn1   │ (None, 32, 32,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu1 │ (None, 32, 32,    │          0 │ stage1_block1_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_conv2 │ (None, 32, 32,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_bn2   │ (None, 32, 32,    │        256 │ stage1_block1_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_add   │ (None, 32, 32,    │          0 │ stage1_block1_bn… │
# │ (Add)               │ 64)               │            │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block1_relu2 │ (None, 32, 32,    │          0 │ stage1_block1_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv1 │ (None, 32, 32,    │     36,928 │ stage1_block1_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn1   │ (None, 32, 32,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu1 │ (None, 32, 32,    │          0 │ stage1_block2_bn… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_conv2 │ (None, 32, 32,    │     36,928 │ stage1_block2_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_bn2   │ (None, 32, 32,    │        256 │ stage1_block2_co… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_add   │ (None, 32, 32,    │          0 │ stage1_block2_bn… │
# │ (Add)               │ 64)               │            │ stage1_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_block2_relu2 │ (None, 32, 32,    │          0 │ stage1_block2_ad… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv1 │ (None, 16, 16,    │     73,856 │ stage1_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn1   │ (None, 16, 16,    │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu1 │ (None, 16, 16,    │          0 │ stage2_block1_bn… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_conv2 │ (None, 16, 16,    │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 16, 16,    │      8,320 │ stage1_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn2   │ (None, 16, 16,    │        512 │ stage2_block1_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_shor… │ (None, 16, 16,    │        512 │ stage2_block1_sh… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 16, 16,    │          0 │ stage2_block1_bn… │
# │ (Add)               │ 128)              │            │ stage2_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu2 │ (None, 16, 16,    │          0 │ stage2_block1_ad… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv1 │ (None, 16, 16,    │    147,584 │ stage2_block1_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn1   │ (None, 16, 16,    │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu1 │ (None, 16, 16,    │          0 │ stage2_block2_bn… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_conv2 │ (None, 16, 16,    │    147,584 │ stage2_block2_re… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_bn2   │ (None, 16, 16,    │        512 │ stage2_block2_co… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 16, 16,    │          0 │ stage2_block2_bn… │
# │ (Add)               │ 128)              │            │ stage2_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_relu2 │ (None, 16, 16,    │          0 │ stage2_block2_ad… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv1 │ (None, 8, 8, 256) │    295,168 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn1   │ (None, 8, 8, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu1 │ (None, 8, 8, 256) │          0 │ stage3_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_conv2 │ (None, 8, 8, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 8, 8, 256) │     33,024 │ stage2_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_bn2   │ (None, 8, 8, 256) │      1,024 │ stage3_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_shor… │ (None, 8, 8, 256) │      1,024 │ stage3_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 8, 8, 256) │          0 │ stage3_block1_bn… │
# │ (Add)               │                   │            │ stage3_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_relu2 │ (None, 8, 8, 256) │          0 │ stage3_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv1 │ (None, 8, 8, 256) │    590,080 │ stage3_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn1   │ (None, 8, 8, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu1 │ (None, 8, 8, 256) │          0 │ stage3_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_conv2 │ (None, 8, 8, 256) │    590,080 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_bn2   │ (None, 8, 8, 256) │      1,024 │ stage3_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 8, 8, 256) │          0 │ stage3_block2_bn… │
# │ (Add)               │                   │            │ stage3_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_relu2 │ (None, 8, 8, 256) │          0 │ stage3_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv1 │ (None, 4, 4, 512) │  1,180,160 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn1   │ (None, 4, 4, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu1 │ (None, 4, 4, 512) │          0 │ stage4_block1_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_conv2 │ (None, 4, 4, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 4, 4, 512) │    131,584 │ stage3_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_bn2   │ (None, 4, 4, 512) │      2,048 │ stage4_block1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_shor… │ (None, 4, 4, 512) │      2,048 │ stage4_block1_sh… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 4, 4, 512) │          0 │ stage4_block1_bn… │
# │ (Add)               │                   │            │ stage4_block1_sh… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_relu2 │ (None, 4, 4, 512) │          0 │ stage4_block1_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv1 │ (None, 4, 4, 512) │  2,359,808 │ stage4_block1_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn1   │ (None, 4, 4, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu1 │ (None, 4, 4, 512) │          0 │ stage4_block2_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_conv2 │ (None, 4, 4, 512) │  2,359,808 │ stage4_block2_re… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_bn2   │ (None, 4, 4, 512) │      2,048 │ stage4_block2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 4, 4, 512) │          0 │ stage4_block2_bn… │
# │ (Add)               │                   │            │ stage4_block1_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_relu2 │ (None, 4, 4, 512) │          0 │ stage4_block2_ad… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ stage4_block2_re… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc (Dense)          │ (None, 2)         │      1,026 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,183,106 (42.66 MB)
#  Trainable params: 9,578,498 (36.54 MB)
#  Non-trainable params: 1,604,608 (6.12 MB)

# %% [markdown]
# # Model Compilation

# %%
# Compile for fine-tuning with lower learning rate
adapted_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',  # Updated to match one-hot encoded labels
    metrics=['accuracy', 'AUC']
)

print(f"\nModel compiled for fine-tuning:")
print(f"  Optimizer: Adam (lr={FINE_TUNE_LR})")
print(f"  Loss: Categorical crossentropy")
print(f"  Metrics: Accuracy, AUC")
# Out:
# Model compiled for fine-tuning:
#   Optimizer: Adam (lr=0.0001)
#   Loss: Categorical crossentropy
#   Metrics: Accuracy, AUC

# %% [markdown]
# # Fine-tuning Setup

# %%
# Generate path for fine-tuned model
tuned_model_path = generate_tuned_model_path(
    original_params, 
    TARGET_SIZE, 
    MODEL_PATH, 
    ARCHITECTURE
)
print(f"Fine-tuned model will be saved to: {tuned_model_path}")

# Setup logger for fine-tuning
logger = ModelLogger()
tuned_model_info = {
    "model_name": f"{ARCHITECTURE}_tuned",
    "original_model": best_model_path,
    "original_size": ORIGINAL_SIZE,
    "target_size": TARGET_SIZE,
    "fine_tune_lr": FINE_TUNE_LR,
    "freeze_ratio": FREEZE_RATIO,
    "epochs": FINE_TUNE_EPOCHS,
    "batch_size": original_params['batch_size'],
    "augmented": original_params['augmented'],
    "dropout_rate": original_params['dropout_rate'],
    "random_seed": RANDOM_SEED
}
logger.initialize_run(tuned_model_info)
# Out:
# Fine-tuned model will be saved to: ../output/models/resnet18_tuned_augmented_b64_lr0.001_dr0.5_64px_pneumonia_model.keras

# %% [markdown]
# # Fine-tuning Training

# %%
# Get callbacks for fine-tuning
callbacks = get_callbacks(
    tuned_model_path,
    monitor='val_AUC',
    mode='max',
    patience=10,
    factor=0.5  # Use lower factor for fine-tuning (more aggressive LR reduction)
)

# Start fine-tuning
print(f"\nStarting fine-tuning for {FINE_TUNE_EPOCHS} epochs...")
start_time = time.time()

history = adapted_model.fit(
    train_dataset,
    validation_data=(val_images, val_labels),
    epochs=FINE_TUNE_EPOCHS,
    callbacks=callbacks,
    verbose=tf_verbosity
)

exec_time = round(time.time() - start_time, 2)
print(f"\nFine-tuning completed in {exec_time} seconds")

# Save training info to logger
logger.add_training_info(history, exec_time)

# Set final model for evaluation
final_model = adapted_model

print("✓ Fine-tuning completed successfully!")

# Plot training history
plot_training_history(history)
# Out:
# Starting fine-tuning for 30 epochs...
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750367224.378922   60405 service.cc:148] XLA service 0x73cf9c02e780 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750367224.378960   60405 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti with Max-Q Design, Compute Capability 7.5
# 2025-06-19 22:07:04.549544: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1750367225.438506   60405 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1750367225.438506   60405 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-19 22:07:06.118929: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.173956: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.118929: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.173956: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.562655: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.562655: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.916096: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:06.916096: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:07.560881: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:07.560881: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[64,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:09.283693: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-19 22:07:09.283693: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-19 22:07:11.835590: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:930] The NVIDIA driver's CUDA version is 12.4 which is older than the PTX compiler version 12.5.82. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# 2025-06-19 22:07:11.835590: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:930] The NVIDIA driver's CUDA version is 12.4 which is older than the PTX compiler version 12.5.82. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#  1/74 ━━━━━━━━━━━━━━━━━━━━ 19:27 16s/step - AUC: 0.9509 - accuracy: 0.9062 - loss: 0.3862
# I0000 00:00:1750367234.217201   60405 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - AUC: 0.9258 - accuracy: 0.8684 - loss: 0.6335
# 2025-06-19 22:07:23.890819: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:23.915872: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.174389: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.174389: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.447353: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.447353: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.995549: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:24.995549: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[36,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[36,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:26.466215: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.38GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-19 22:07:26.466215: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.38GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - AUC: 0.9260 - accuracy: 0.8686 - loss: 0.6307
# 2025-06-19 22:07:32.623064: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:32.650334: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:32.876053: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:32.876053: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:33.121437: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:33.121437: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:33.568553: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:33.568553: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.617101: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.621297: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.775921: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.617101: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.621297: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.775921: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.969281: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:35.969281: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:36.251818: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:07:36.251818: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[12,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 318ms/step - AUC: 0.9263 - accuracy: 0.8688 - loss: 0.6279 - val_AUC: 0.9170 - val_accuracy: 0.7462 - val_loss: 0.6994 - learning_rate: 1.0000e-04
# Epoch 2/30
# Epoch 2/30
# /home/miguel/Desktop/CAA/CAA_Project2/venv/lib/python3.12/site-packages/keras/src/callbacks/model_checkpoint.py:209: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /home/miguel/Desktop/CAA/CAA_Project2/venv/lib/python3.12/site-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: AUC,accuracy,loss,val_AUC,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9710 - accuracy: 0.9090 - loss: 0.2223 - val_AUC: 0.9348 - val_accuracy: 0.8149 - val_loss: 0.3663 - learning_rate: 1.0000e-04
# Epoch 3/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9710 - accuracy: 0.9090 - loss: 0.2223 - val_AUC: 0.9348 - val_accuracy: 0.8149 - val_loss: 0.3663 - learning_rate: 1.0000e-04
# Epoch 3/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - AUC: 0.9816 - accuracy: 0.9319 - loss: 0.1705 - val_AUC: 0.9873 - val_accuracy: 0.9485 - val_loss: 0.1486 - learning_rate: 1.0000e-04
# Epoch 4/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - AUC: 0.9816 - accuracy: 0.9319 - loss: 0.1705 - val_AUC: 0.9873 - val_accuracy: 0.9485 - val_loss: 0.1486 - learning_rate: 1.0000e-04
# Epoch 4/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9838 - accuracy: 0.9396 - loss: 0.1614 - val_AUC: 0.9896 - val_accuracy: 0.9580 - val_loss: 0.1290 - learning_rate: 1.0000e-04
# Epoch 5/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9838 - accuracy: 0.9396 - loss: 0.1614 - val_AUC: 0.9896 - val_accuracy: 0.9580 - val_loss: 0.1290 - learning_rate: 1.0000e-04
# Epoch 5/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9864 - accuracy: 0.9410 - loss: 0.1474 - val_AUC: 0.9813 - val_accuracy: 0.9218 - val_loss: 0.1771 - learning_rate: 1.0000e-04
# Epoch 6/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9864 - accuracy: 0.9410 - loss: 0.1474 - val_AUC: 0.9813 - val_accuracy: 0.9218 - val_loss: 0.1771 - learning_rate: 1.0000e-04
# Epoch 6/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - AUC: 0.9878 - accuracy: 0.9462 - loss: 0.1378 - val_AUC: 0.9896 - val_accuracy: 0.9637 - val_loss: 0.1233 - learning_rate: 1.0000e-04
# Epoch 7/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - AUC: 0.9878 - accuracy: 0.9462 - loss: 0.1378 - val_AUC: 0.9896 - val_accuracy: 0.9637 - val_loss: 0.1233 - learning_rate: 1.0000e-04
# Epoch 7/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9875 - accuracy: 0.9410 - loss: 0.1412 - val_AUC: 0.9842 - val_accuracy: 0.9275 - val_loss: 0.1608 - learning_rate: 1.0000e-04
# Epoch 8/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9875 - accuracy: 0.9410 - loss: 0.1412 - val_AUC: 0.9842 - val_accuracy: 0.9275 - val_loss: 0.1608 - learning_rate: 1.0000e-04
# Epoch 8/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9902 - accuracy: 0.9491 - loss: 0.1244 - val_AUC: 0.9914 - val_accuracy: 0.9485 - val_loss: 0.1187 - learning_rate: 1.0000e-04
# Epoch 9/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9902 - accuracy: 0.9491 - loss: 0.1244 - val_AUC: 0.9914 - val_accuracy: 0.9485 - val_loss: 0.1187 - learning_rate: 1.0000e-04
# Epoch 9/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9907 - accuracy: 0.9520 - loss: 0.1231 - val_AUC: 0.9911 - val_accuracy: 0.9561 - val_loss: 0.1220 - learning_rate: 1.0000e-04
# Epoch 10/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9907 - accuracy: 0.9520 - loss: 0.1231 - val_AUC: 0.9911 - val_accuracy: 0.9561 - val_loss: 0.1220 - learning_rate: 1.0000e-04
# Epoch 10/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9908 - accuracy: 0.9524 - loss: 0.1210 - val_AUC: 0.9913 - val_accuracy: 0.9695 - val_loss: 0.1103 - learning_rate: 1.0000e-04
# Epoch 11/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9908 - accuracy: 0.9524 - loss: 0.1210 - val_AUC: 0.9913 - val_accuracy: 0.9695 - val_loss: 0.1103 - learning_rate: 1.0000e-04
# Epoch 11/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9927 - accuracy: 0.9642 - loss: 0.1040 - val_AUC: 0.9934 - val_accuracy: 0.9599 - val_loss: 0.1022 - learning_rate: 1.0000e-04
# Epoch 12/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9927 - accuracy: 0.9642 - loss: 0.1040 - val_AUC: 0.9934 - val_accuracy: 0.9599 - val_loss: 0.1022 - learning_rate: 1.0000e-04
# Epoch 12/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9928 - accuracy: 0.9577 - loss: 0.1041 - val_AUC: 0.9834 - val_accuracy: 0.9237 - val_loss: 0.1661 - learning_rate: 1.0000e-04
# Epoch 13/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9928 - accuracy: 0.9577 - loss: 0.1041 - val_AUC: 0.9834 - val_accuracy: 0.9237 - val_loss: 0.1661 - learning_rate: 1.0000e-04
# Epoch 13/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9941 - accuracy: 0.9649 - loss: 0.0946 - val_AUC: 0.9937 - val_accuracy: 0.9676 - val_loss: 0.1017 - learning_rate: 1.0000e-04
# Epoch 14/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9941 - accuracy: 0.9649 - loss: 0.0946 - val_AUC: 0.9937 - val_accuracy: 0.9676 - val_loss: 0.1017 - learning_rate: 1.0000e-04
# Epoch 14/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9936 - accuracy: 0.9599 - loss: 0.0999 - val_AUC: 0.9922 - val_accuracy: 0.9618 - val_loss: 0.1125 - learning_rate: 1.0000e-04
# Epoch 15/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9936 - accuracy: 0.9599 - loss: 0.0999 - val_AUC: 0.9922 - val_accuracy: 0.9618 - val_loss: 0.1125 - learning_rate: 1.0000e-04
# Epoch 15/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - AUC: 0.9928 - accuracy: 0.9612 - loss: 0.1020 - val_AUC: 0.9908 - val_accuracy: 0.9485 - val_loss: 0.1222 - learning_rate: 1.0000e-04
# Epoch 16/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - AUC: 0.9928 - accuracy: 0.9612 - loss: 0.1020 - val_AUC: 0.9908 - val_accuracy: 0.9485 - val_loss: 0.1222 - learning_rate: 1.0000e-04
# Epoch 16/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9933 - accuracy: 0.9646 - loss: 0.1005 - val_AUC: 0.9939 - val_accuracy: 0.9676 - val_loss: 0.0978 - learning_rate: 1.0000e-04
# Epoch 17/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9933 - accuracy: 0.9646 - loss: 0.1005 - val_AUC: 0.9939 - val_accuracy: 0.9676 - val_loss: 0.0978 - learning_rate: 1.0000e-04
# Epoch 17/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9939 - accuracy: 0.9647 - loss: 0.0974 - val_AUC: 0.9937 - val_accuracy: 0.9714 - val_loss: 0.0987 - learning_rate: 1.0000e-04
# Epoch 18/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9939 - accuracy: 0.9647 - loss: 0.0974 - val_AUC: 0.9937 - val_accuracy: 0.9714 - val_loss: 0.0987 - learning_rate: 1.0000e-04
# Epoch 18/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9950 - accuracy: 0.9699 - loss: 0.0824 - val_AUC: 0.9688 - val_accuracy: 0.8912 - val_loss: 0.2284 - learning_rate: 1.0000e-04
# Epoch 19/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9950 - accuracy: 0.9699 - loss: 0.0824 - val_AUC: 0.9688 - val_accuracy: 0.8912 - val_loss: 0.2284 - learning_rate: 1.0000e-04
# Epoch 19/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9936 - accuracy: 0.9629 - loss: 0.0968 - val_AUC: 0.9937 - val_accuracy: 0.9733 - val_loss: 0.0875 - learning_rate: 1.0000e-04
# Epoch 20/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9936 - accuracy: 0.9629 - loss: 0.0968 - val_AUC: 0.9937 - val_accuracy: 0.9733 - val_loss: 0.0875 - learning_rate: 1.0000e-04
# Epoch 20/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - AUC: 0.9947 - accuracy: 0.9676 - loss: 0.0871 - val_AUC: 0.9883 - val_accuracy: 0.9485 - val_loss: 0.1382 - learning_rate: 1.0000e-04
# Epoch 21/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - AUC: 0.9947 - accuracy: 0.9676 - loss: 0.0871 - val_AUC: 0.9883 - val_accuracy: 0.9485 - val_loss: 0.1382 - learning_rate: 1.0000e-04
# Epoch 21/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9945 - accuracy: 0.9673 - loss: 0.0896 - val_AUC: 0.9809 - val_accuracy: 0.9313 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 22/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9945 - accuracy: 0.9673 - loss: 0.0896 - val_AUC: 0.9809 - val_accuracy: 0.9313 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 22/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9957 - accuracy: 0.9682 - loss: 0.0824 - val_AUC: 0.9938 - val_accuracy: 0.9714 - val_loss: 0.0864 - learning_rate: 1.0000e-04
# Epoch 23/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9957 - accuracy: 0.9682 - loss: 0.0824 - val_AUC: 0.9938 - val_accuracy: 0.9714 - val_loss: 0.0864 - learning_rate: 1.0000e-04
# Epoch 23/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9952 - accuracy: 0.9677 - loss: 0.0875 - val_AUC: 0.9922 - val_accuracy: 0.9676 - val_loss: 0.0987 - learning_rate: 1.0000e-04
# Epoch 24/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9952 - accuracy: 0.9677 - loss: 0.0875 - val_AUC: 0.9922 - val_accuracy: 0.9676 - val_loss: 0.0987 - learning_rate: 1.0000e-04
# Epoch 24/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9934 - accuracy: 0.9599 - loss: 0.0979 - val_AUC: 0.9921 - val_accuracy: 0.9676 - val_loss: 0.1030 - learning_rate: 1.0000e-04
# Epoch 25/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - AUC: 0.9934 - accuracy: 0.9599 - loss: 0.0979 - val_AUC: 0.9921 - val_accuracy: 0.9676 - val_loss: 0.1030 - learning_rate: 1.0000e-04
# Epoch 25/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9943 - accuracy: 0.9665 - loss: 0.0909 - val_AUC: 0.9878 - val_accuracy: 0.9637 - val_loss: 0.1327 - learning_rate: 1.0000e-04
# Epoch 26/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9943 - accuracy: 0.9665 - loss: 0.0909 - val_AUC: 0.9878 - val_accuracy: 0.9637 - val_loss: 0.1327 - learning_rate: 1.0000e-04
# Epoch 26/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9947 - accuracy: 0.9730 - loss: 0.0834 - val_AUC: 0.9908 - val_accuracy: 0.9504 - val_loss: 0.1206 - learning_rate: 1.0000e-04
# Epoch 27/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9947 - accuracy: 0.9730 - loss: 0.0834 - val_AUC: 0.9908 - val_accuracy: 0.9504 - val_loss: 0.1206 - learning_rate: 1.0000e-04
# Epoch 27/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9960 - accuracy: 0.9710 - loss: 0.0781 - val_AUC: 0.9928 - val_accuracy: 0.9618 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 28/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9960 - accuracy: 0.9710 - loss: 0.0781 - val_AUC: 0.9928 - val_accuracy: 0.9618 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 28/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9951 - accuracy: 0.9684 - loss: 0.0860 - val_AUC: 0.9949 - val_accuracy: 0.9714 - val_loss: 0.0896 - learning_rate: 5.0000e-05
# Epoch 29/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9951 - accuracy: 0.9684 - loss: 0.0860 - val_AUC: 0.9949 - val_accuracy: 0.9714 - val_loss: 0.0896 - learning_rate: 5.0000e-05
# Epoch 29/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9962 - accuracy: 0.9713 - loss: 0.0754 - val_AUC: 0.9942 - val_accuracy: 0.9695 - val_loss: 0.0995 - learning_rate: 5.0000e-05
# Epoch 30/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - AUC: 0.9962 - accuracy: 0.9713 - loss: 0.0754 - val_AUC: 0.9942 - val_accuracy: 0.9695 - val_loss: 0.0995 - learning_rate: 5.0000e-05
# Epoch 30/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9955 - accuracy: 0.9745 - loss: 0.0783 - val_AUC: 0.9958 - val_accuracy: 0.9733 - val_loss: 0.0793 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - AUC: 0.9955 - accuracy: 0.9745 - loss: 0.0783 - val_AUC: 0.9958 - val_accuracy: 0.9733 - val_loss: 0.0793 - learning_rate: 5.0000e-05
#
# Fine-tuning completed in 301.36 seconds
# ✓ Fine-tuning completed successfully!
#
# Fine-tuning completed in 301.36 seconds
# ✓ Fine-tuning completed successfully!

# %% [markdown]
# # Evaluation

# %%
# Evaluate the fine-tuned model (using model from memory)
print("\nEvaluating fine-tuned model on test set...")

# Evaluate using the final model
results = evaluate_model(final_model, test_images, test_labels, verbose=tf_verbosity)

# Add evaluation results to logger
logger.add_evaluation_results(results)

# Plot results
plot_roc_curve(results['roc']['fpr'], results['roc']['tpr'], results['roc']['auc'])
plot_confusion_matrix(results['confusion_matrix'])
print("\nClassification Report:")
print(results['classification_report'])
# Out:
# Evaluating fine-tuned model on test set...
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - AUC: 0.9577 - accuracy: 0.9066 - loss: 0.3077
# 2025-06-19 22:12:01.074544: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1,64,64]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.113458: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.321979: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.321979: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,16,16]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.544026: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.544026: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,8,8]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.973968: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-19 22:12:01.973968: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,4,4]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - AUC: 0.9580 - accuracy: 0.9060 - loss: 0.3065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - AUC: 0.9580 - accuracy: 0.9060 - loss: 0.3065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step
# ROC AUC Score: 0.974655
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.76      0.85       234
#    Pneumonia       0.87      0.98      0.93       390
#
#     accuracy                           0.90       624
#    macro avg       0.92      0.87      0.89       624
# weighted avg       0.91      0.90      0.90       624

# %% [markdown]
# # Save Results

# %%
# Save fine-tuning log
tuned_log_path = os.path.join(LOG_PATH, f"{ARCHITECTURE}_tuned_{TARGET_SIZE}px_info.json")
logger.save(tuned_log_path)

print(f"\n✅ Fine-tuning completed successfully!")
print(f"📁 Model saved: {tuned_model_path}")
print(f"📊 Logs saved: {tuned_log_path}")
print(f"🎯 Final accuracy: {results['test_accuracy']:.4f}")
print(f"📈 Final AUC: {results['test_auc']:.4f}")
print(f"🔍 The ResNet18 model is now ready for XAI analysis at {TARGET_SIZE}x{TARGET_SIZE} resolution.")
# Out:
# Run information saved to ../output/logs/resnet18_tuned_64px_info.json
#
# ✅ Fine-tuning completed successfully!
# 📁 Model saved: ../output/models/resnet18_tuned_augmented_b64_lr0.001_dr0.5_64px_pneumonia_model.keras
# 📊 Logs saved: ../output/logs/resnet18_tuned_64px_info.json
# 🎯 Final accuracy: 0.9006
# 📈 Final AUC: 0.9591
# 🔍 The ResNet18 model is now ready for XAI analysis at 64x64 resolution.
